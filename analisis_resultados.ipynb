# %%
import pandas as pd
import numpy as np

# %%
tabla_resultado_hbos = pd.read_excel('HBOS_tabla_anomalos_emicron.xlsx')
tabla_resultado_rn = pd.read_excel('RN_tabla_anomalos.xlsx')

# %%
tabla_resultado_hbos.shape
# Out:
# (13, 144)

# %%
merge_df = pd.merge(tabla_resultado_hbos, tabla_resultado_rn, left_index = True, right_index = True, suffixes = ('id_hbos', 'id_rn'), how = 'inner')

# %%
merge_df.shape
# Out:
# (13, 302)

# %%
merge_df.head()
# Out:
#    idid_hbos  cod_deptoid_hbos  areaid_hbos  clase_teid_hbos  p35id_hbos  \
# 0  554192513                76    76.000000                1           2
# 1  557936913                47    36.133191                2           2
# 2  536955111                52    52.000000                1           1
# 3  552299513                66    66.000000                1           2
# 4  555056711                63    63.000000                1           2
#
#    p241id_hbos  p3031id_hbos  p3032_1id_hbos  p3032_2id_hbos  p3032_3id_hbos  \
# 0           66             2         0.43254        0.279762        0.605159
# 1           39             2         0.43254        0.279762        0.605159
# 2           33             2         0.43254        0.279762        0.605159
# 3           55             2         0.43254        0.279762        0.605159
# 4           58             2         0.43254        0.279762        0.605159
#
#    ...  p4030id_rn  p4031  p4032  p4038id_rn  p3072id_rn  \
# ...
