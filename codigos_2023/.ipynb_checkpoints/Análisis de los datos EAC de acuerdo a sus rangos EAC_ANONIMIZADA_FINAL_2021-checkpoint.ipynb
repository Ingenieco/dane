# %%
# Bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Cargamos los datos de la base de datos anonimizada 
data = pd.read_excel('EAC_2021_ANONIMIZADA_FINAL.xlsx')

# %%
# primer vistazo de los datos

print(data.shape)
data.head()
# Out:
# (9884, 64)
#        V1 CORRELA_16    CORRE_9  IDOJ1  IDAIO  CIMREP      BRUTA    CONSUI  \
# 0  987664   4711-472    471-472   11.0   1986     0.0   463090.0   91851.0
# 1  987666        462    462-463   14.0   1996     0.0   536279.0   75620.0
# 2  987667  4771-4751  476 - 477    4.0   1991     0.0   162440.0   22450.0
# 3  987668        466    466-469   14.0   1986     0.0  1671695.0  812440.0
# 4  987669        473        473    5.0   2004     0.0  1467590.0  200028.0
#
#      GAS  EMPAQUE  ...     INVINI     INVFIN    ROTACION     INVPRO  \
# 0    0.0      0.0  ...  1927857.0  2409090.0   4928377.0  2168473.5
# 1  720.0   3000.0  ...   590035.0     3193.0   6006680.0   296614.0
# 2    0.0      0.0  ...   381201.0   431759.0    397696.0   406480.0
# 3    0.0      0.0  ...  1300668.0  1963161.0  11099022.0  1631914.5
# 4    0.0      0.0  ...   110756.0   141377.0   6421609.0   126066.5
#
#           CTO      CTOINS  VENTASNOP      GASTOS  GASTOSNOP   GASTOPNOP
# ...

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container{ width:98% }</style>"))
# Out:
# C:\Users\LenovoP50\AppData\Local\Temp\ipykernel_17332\3261091095.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container{ width:98% }</style>

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9884 entries, 0 to 9883
# Data columns (total 64 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   V1           9884 non-null   int64
#  1   CORRELA_16   9884 non-null   object
#  2   CORRE_9      9884 non-null   object
#  3   IDOJ1        9876 non-null   float64
#  4   IDAIO        9884 non-null   int64
#  5   CIMREP       9884 non-null   float64
#  6   BRUTA        9884 non-null   float64
#  7   CONSUI       9884 non-null   float64
#  8   GAS          9884 non-null   float64
#  9   EMPAQUE      9884 non-null   float64
#  10  HONORA       9884 non-null   float64
#  11  COMISION     9884 non-null   float64
#  12  ARRIENDO     9884 non-null   float64
#  13  SEGURO       9884 non-null   float64
#  14  ASEO         9884 non-null   float64
#  15  ENERGIA      9884 non-null   float64
#  16  COMUNICA     9884 non-null   float64
#  17  PUBLICO      9884 non-null   float64
# ...

# %%
# límites inferior y superior para cada variable
limits = {
    'BRUTA': [-1237598, 2385146819],
    'CONSUI': [0, 5494553345],
    'GAS': [0, 2370388],
    'EMPAQUE': [0, 37830162],
    'HONORA': [0, 62219911],
    'COMISION': [0, 51516432],
    'ARRIENDO': [0, 99522795],
    'SEGURO': [0, 121689256],
    'ASEO': [0, 58086513],
    'ENERGIA': [0, 103339529],
    'COMUNICA': [0, 7962585],
    'PUBLICO': [0, 9578311],
    'FLETES': [0, 22114684],
    'PUBLICI': [0, 130259795],
    'ADECUA': [0, 35458429],
    'REGALA': [0, 28212722],
    'OUTSOURCING': [0, 24320469],
    'OTROS': [0, 34952586],
    'SUELDOS': [0, 245633492],
    'PRESTAC': [0, 145132285],
    'VENTA': [0, 6469961995],
    'AGREGA': [-5402320, 670756065],
    'PERREMUN': [0, 17293],
    'SOCIOS': [0, 73],
    'PERSONOM': [0, 15440],
    'DIRECTO': [0, 4789],
    'AGENCIA': [0, 2842],
    'APRENDIZ': [0, 968],
    'TOTPERSO': [0, 21103],
    'PROMUJ': [0, 14],
    'PROHOM': [0, 71],
    'PERMUJ': [0, 7407],
    'PERHOM': [0, 8034],
    'DIRMUJ': [0, 2922],
    'DIRHOM': [0, 1867],
    'AGEMUJ': [0, 1737],
    'AGEHOM': [0, 1106],
    'APRENMUJ': [0, 544],
    'APRENHOM': [0, 425],
    'TOTMUJ': [0, 10544],
    'TOTHOM': [0, 10559],
    'SUEPLAN': [0, 218846382],
    'PREPLAN': [0, 96905297],
    'REMPLAN': [0, 309841573],
    'COTIZA': [0, 44788154],
    'GASAGEN': [0, 39606191],
    'REMTEMP': [0, 54299387],
    'TOTREM': [0, 374155945],
    'INVINI': [0, 1455000000],
    'INVFIN': [0, 935392262],
    'ROTACION': [0, 5249750596],
    'INVPRO': [0, 1195196131],
    'CTO': [0, 5249750596],
    'GASTOS': [0, 5888826656],
    'GASTOSNOP': [0, 907038000],
    'GASTOPNOP': [0, 66581671559]
}

# Creamos un DataFrame con los límites
limits_df = pd.DataFrame.from_dict(limits, orient='index', columns=['LIMITE_INFERIOR', 'LIMITE_SUPERIOR'])

# Iteramos sobre cada variable y evaluamos los límites
for variable, (lim_inf, lim_sup) in limits.items():
    # Obtenemos las filas que están fuera de los límites
    outliers = data[(data[variable] < lim_inf) | (data[variable] > lim_sup)]
    
    # Imprimimos la información sobre la variable
    print(f'\nVariable: {variable}')
    print(f'Límite Inferior: {lim_inf}\tLímite Superior: {lim_sup}')
    
    # Imprimimos las filas con valores fuera de los límites
    if not outliers.empty:
        print('\nValores fuera de los límites:')
        print(outliers)
    else:
        print('Todos los valores están dentro de los límites.')
# Out:
# Variable: BRUTA
# Límite Inferior: -1237598	Límite Superior: 2385146819
# Todos los valores están dentro de los límites.
#
# Variable: CONSUI
# Límite Inferior: 0	Límite Superior: 5494553345
# Todos los valores están dentro de los límites.
#
# Variable: GAS
# Límite Inferior: 0	Límite Superior: 2370388
# Todos los valores están dentro de los límites.
#
# Variable: EMPAQUE
# Límite Inferior: 0	Límite Superior: 37830162
# Todos los valores están dentro de los límites.
#
# Variable: HONORA
# Límite Inferior: 0	Límite Superior: 62219911
#
# Valores fuera de los límites:
#            V1 CORRELA_16  CORRE_9  IDOJ1  IDAIO  CIMREP        BRUTA  \
# 4663  1223982        462  462-463    5.0   1999     0.0  312254269.0
#
#            CONSUI      GAS  EMPAQUE  ...       INVINI       INVFIN  \
# 4663  264969799.5  63883.0      0.0  ...  277355968.0  122307086.0
#
#          ROTACION       INVPRO          CTO       CTOINS  VENTASNOP  \
# ...
